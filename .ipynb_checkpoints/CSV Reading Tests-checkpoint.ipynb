# %%
import csv
from __future__ import division
PATH_TO_DATA = "data/Valence, Arousal, Dominance - Ratings_Warriner_et_al.csv"
word_info = {}

def rescale(values, new_min, new_max):
    output = []
    old_min, old_max = min(values), max(values)

    for v in values:
        new_v = (new_max - new_min) / (old_max - old_min) * (v - old_min) + new_min
        output.append(new_v)
    return output

def readValAroCSV():
    with open(PATH_TO_DATA, 'rb') as f:
        reader = csv.reader(f)
        reader.next()
        for row in reader:
            word = row.pop(0)
            word_info[word]=row
            # for row - ValAvg, ValRat, AroAvg, AroRat, DomAvg, DomRat
readValAroCSV()

# %%
# code to reload the py code/ notebook
# %load_ext autoreload
# %autoreload 2

# %%
reader = csv.reader(open("data/songData.csv"))
songDict = {}
reader.next()
for row in reader:
    key = row[0]
    lyric = row[1].split()
    songDict[key] = lyric

# %%
#from __future__ import division
song_avg_emotion_val = {}

def generateBOW(songLyrics):
    bow = {} 
    for word in songLyrics:
        if word not in bow.keys():
            bow[word] = 1
        else:
            bow[word] += 1
    return bow

def calculate(songDict):
    for name, lyrics in songDict.items():
        
        # generate a hashmap
        numWords = len(lyrics)
        lyricsBOW = generateBOW(lyrics)
        
        avg_val = 0
        avg_aro = 0
        #avg_dom = 0
        # currently ignoring dominance values since we don't have a comparator 
        
        # get corresponding VAD in word_info
        for word, count in lyricsBOW.items():
            # do nothing if it's not in word_info
            if word not in word_info:
                numWords -= count
                continue
            # if it is inside
            # add to running avg of song - 3 total values  
            # perhaps include perceptron? 
            word_values = word_info[word]
        
            #print "avg_val is:", avg_val
            avg_val += float(word_values[0])*count
            avg_aro += float(word_values[2])*count
            #avg_dom += float(word_values[4])*count
            
        f_avg_val = avg_val/numWords
        f_avg_aro = avg_aro/numWords
        #f_avg_dom = avg_dom/numWords
        #song_avg_emotion_val[name] = [f_avg_val, f_avg_aro, f_avg_dom]
        song_avg_emotion_val[name] = [f_avg_val, f_avg_aro]
calculate(songDict)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-31-5752af2ac70f> in <module>()
#      44         #song_avg_emotion_val[name] = [f_avg_val, f_avg_aro, f_avg_dom]
#      45         song_avg_emotion_val[name] = [f_avg_val, f_avg_aro]
# ---> 46 calculate(songDict)
#
# <ipython-input-31-5752af2ac70f> in calculate(songDict)
#      39             #avg_dom += float(word_values[4])*count
#      40
# ---> 41         f_avg_val = avg_val/numWords
#      42         f_avg_aro = avg_aro/numWords
#      43         #f_avg_dom = avg_dom/numWords
#
# ZeroDivisionError: division by zero

# %%
#maxVal = max(song_avg_emotion_val.iteritems(), key=operator.itemgetter(0))[1][0]
maxVal = max(song_avg_emotion_val.iteritems(), key=lambda x: x[1][0])[1][0]
minVal = min(song_avg_emotion_val.iteritems(), key=lambda x: x[1][0])[1][0]
maxAro = max(song_avg_emotion_val.iteritems(), key=lambda x: x[1][1])[1][1]
minAro = min(song_avg_emotion_val.iteritems(), key=lambda x: x[1][1])[1][1]
#print song_avg_emotion_val['let it go']
# Out:
# 5.8775
# 3.29

# %%
emotionVals = {}

def readEmotionVals():
    # calculate valence
    with open("data/Emotion Values.csv") as f:
        reader = csv.reader(f)
        reader.next()
        emoVal = [float(x[1]) for x in reader]
        f_emoVals = rescale(emoVal, minVal, maxVal)
    
    # calculate arousal        
    with open("data/Emotion Values.csv") as f: 
        reader = csv.reader(f)
        reader.next()
        emoAro = [float(x[2]) for x in reader]
        f_emoAro = rescale(emoAro, minAro, maxAro)
    
    # word    
    with open("data/Emotion Values.csv") as f: 
        reader = csv.reader(f)
        reader.next()
        emotions = [x[0] for x in reader]
    
    for i in range(len(emotions)):
        emotionVals[emotions[i]] = [f_emoVals[i], f_emoAro[i]]

readEmotionVals()

# %%
#def matchEmotion():

from functools import partial 
#import operator
print song_avg_emotion_val['bye bye bye']

def printNicely(wordList):
    for emotion in wordList:
        print emotion
# sorted emotions by valence - lowest to greatest
sorted_emoVal = sorted(emotionVals.items(), key=lambda pair: pair[1])
#printNicely(sorted_emoVal)
#print

#for each song, compare the valence and arousals 
def distance_squared(x, emotionVals):
    y = emotionVals[1]
    return (x[0] - y[0])**2 + (x[1]-y[1])**2

#print min(sorted_emoVal, key=partial(distance_squared, song_avg_emotion_val['bye bye bye']))
song_emotion_mapping = {}
for song, values in song_avg_emotion_val.items():
    closestEmotion = min(sorted_emoVal, key=partial(distance_squared, values))
    song_emotion_mapping[song] = closestEmotion[0]
print song_emotion_mapping
# Out:
# [5.552966101694915, 4.460677966101695]
# {'happily ever after': 'pensive', 'only the lonely': 'melancholy', 'say you love me': 'impressed', 'empty garden hey hey johnny': 'sleepy', 'follow you down': 'pensive', 'fall for you': 'pensive', 'calling all angels': 'pensive', 'breakout': 'pensive', 'i wanna be bad': 'melancholy', 'where do broken hearts go': 'pensive', 'mirage': 'pensive', 'day n nite': 'worried', 'stayin alive': 'impressed', 'miss me blind': 'melancholy', 'no lie': 'apathetic', 'the beach boys medley': 'impressed', 'disco nights rockfreak': 'impressed', 'right round': 'pensive', 'harden my heart': 'pensive', 'the jump off': 'worried', 'patches': 'pensive', 'puppy love': 'impressed', 'dazz': 'amused', 'slow hand': 'worried', 'yes we can can': 'sleepy', 'iesha': 'pensive', 'hollywood nights': 'pensive', 'where the party at': 'pensive', 'three little pigs': 'pensive', 'thats the way love goes': 'impressed', 'thank the lord for the night time': 'pensive', 'baby dont forget my number': 'pensive', 'forgot about dre': 'worried', 'here you come again': 'impressed', 'youre my soul and inspiration': 'impressed', 'green light': 'impressed', 'king of anything': 'worried', 'naked eye': 'pensive', 'never had a dream come true': 'pensive', 'red dirt road': 'worried', 'i wish': 'pensive', 'one of us': 'pensive', 'thinkin back': 'contemplative', 'rise': 'pensive', 'misunderstanding': 'melancholy', 'one woman': 'contemplative', 'one wish': 'peaceful', 'just like starting over': 'impressed', 'feels so right': 'impressed', 'this used to be my playground': 'pensive', 'one of a kind love affair': 'impressed', 'nite and day': 'contemplative', 'break it down again': 'worried', 'too shy': 'melancholy', 'you should hear how she talks about you': 'pensive', 'friend of mine': 'pensive', 'thnks fr th mmrs': 'peaceful', 'starships': 'pensive', 'out of the blue': 'contemplative', 'brown eyed girl': 'pensive', 'im so excited': 'impressed', 'i hate myself for loving you': 'apathetic', 'the fox what does the fox say': 'pensive', 'beautiful day': 'pensive', 'my dingaling': 'pensive', 'frozen': 'worried', 'feel so close': 'impressed', 'venus': 'impressed', 'dont you worry child': 'apathetic', 'shouldve known better': 'apathetic', 'baby its you': 'pensive', 'little red corvette': 'worried', 'danger been so long': 'worried', 'sweet city woman': 'contemplative', 'im not in love': 'worried', 'dark lady': 'pensive', 'our love': 'hopeful', 'this girls in love with you': 'contemplative', 'money power  respect': 'impressed', 'coward of the county': 'worried', 'you and tequila': 'worried', 'oh sheila': 'impressed', 'a little bit me a little bit you': 'worried', 'for your eyes only': 'peaceful', 'short people': 'melancholy', 'all those years ago': 'pensive', 'baby im for real': 'impressed', 'beer for my horses': 'worried', 'whip appeal': 'worried', 'i dont want to miss a thing': 'melancholy', 'my eyes adored you': 'pensive', 'poison': 'worried', 'angel eyes': 'pensive', 'goodnight tonight': 'worried', 'no diggity': 'pensive', 'do you wanna make love': 'worried', 'cats in the cradle': 'contemplative', 'heart and soul': 'impressed', 'the remedy i wont worry': 'apathetic', 'the valley road': 'tired', 'the way we weretry to remember': 'pensive', 'a hazy shade of winter': 'melancholy', 'goldfinger': 'impressed', 'i know': 'peaceful', 'cant we try': 'pensive', 'kiss kiss': 'pensive', 'hero': 'impressed', 'easy come easy go': 'contemplative', 'pontoon': 'pensive', 'never my love': 'impressed', 'here': 'pensive', 'in my head': 'pensive', 'snowbird': 'pensive', 'union of the snake': 'apathetic', 'studio': 'worried', 'trapped by a thing called love': 'worried', 'if u seek amy': 'worried', 'right place wrong time': 'worried', 'american pie': 'worried', 'expressway to your heart': 'embarassed', 'celebration': 'amused', 'do you really want to hurt me': 'apathetic', 'this is the night': 'pensive', 'she wants to dance with me': 'impressed', 'nothing from nothing': 'pensive', 'never gonna give you up': 'worried', 'h ...

# %%
from calculate import *
main()
